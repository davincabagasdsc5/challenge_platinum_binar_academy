# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('indonesian')
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
nltk.corpus.stopwords.words('indonesian')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Error loading indonesian: Package 'indonesian' not found
# [nltk_data]     in index
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ['ada',
#  'adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
# ...

# %%
#!dir
# Out:
#  Volume in drive D is Data
#  Volume Serial Number is 86AA-243D
#
#  Directory of d:\Binar Academy - Data Science\challenge_platinum
#
# 16/02/2023  19:25    <DIR>          .
# 16/02/2023  19:25    <DIR>          ..
# 16/02/2023  19:18         2.186.718 train_preprocess.tsv.txt
#                1 File(s)      2.186.718 bytes
#                2 Dir(s)  169.941.155.840 bytes free

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/platinum challenge/train_preprocess.tsv.txt", sep="\t", engine="python", names=["data", "label"])

# %%
df
# Out:
#                                                     data     label
# 0      warung ini dimiliki oleh pengusaha pabrik tahu...  positive
# 1      mohon ulama lurus dan k212 mmbri hujjah partai...   neutral
# 2      lokasi strategis di jalan sumatera bandung . t...  positive
# 3      betapa bahagia nya diri ini saat unboxing pake...  positive
# 4      duh . jadi mahasiswa jangan sombong dong . kas...  negative
# ...                                                  ...       ...
# 10995                                       tidak kecewa  positive
# 10996  enak rasa masakan nya apalagi kepiting yang me...  positive
# 10997        hormati partai-partai yang telah berkoalisi   neutral
# 10998  pagi pagi di tol pasteur sudah macet parah , b...  negative
# 10999  meskipun sering belanja ke yogya di riau junct...  positive
#
# [11000 rows x 2 columns]

# %%
df.shape
# Out:
# (11000, 2)

# %%
def cleansing(text):
    # Make sentence being lowercase
    text = text.lower()

    # Remove user, rt, \n, retweet, \t, url, xd
    pattern_1 = r'(user|retweet|\\t|\\r|url|xd)'
    text = re.sub(pattern_1, '', text)

    # Remove mention
    pattern_2 = r'@[^\s]+'
    text = re.sub(pattern_2, '', text)

    # Remove hashtag
    pattern_3 = r'#([^\s]+)'
    text = re.sub(pattern_3, '', text)

    # Remove general punctuation, math operation char, etc.
    pattern_4 = r'[\,\@\*\_\-\!\:\;\?\'\.\"\)\(\{\}\<\>\+\%\$\^\#\/\`\~\|\&\|]'
    text = re.sub(pattern_4, ' ', text)

    # Remove single character
    pattern_5 = r'\b\w{1,3}\b'
    text = re.sub(pattern_5, '', text)

    # Remove emoji
    pattern_6 = r'\\[a-z0-9]{1,5}'
    text = re.sub(pattern_6, '', text)

    # Remove digit character
    pattern_7 = r'\d+'
    text = re.sub(pattern_7, '', text)

    # Remove url start with http or https
    pattern_8 = r'(https|https:)'
    text = re.sub(pattern_8, '', text)

    # Remove (\); ([); (])
    pattern_9 = r'[\\\]\[]'
    text = re.sub(pattern_9, '', text)

    # Remove character non ASCII
    pattern_10 = r'[^\x00-\x7f]'
    text = re.sub(pattern_10, '', text)

    # Remove character non ASCII
    pattern_11 = r'(\\u[0-9A-Fa-f]+)'
    text = re.sub(pattern_11, '', text)

    # Remove multiple whitespace
    pattern_12 = r'(\s+|\\n)'
    text = re.sub(pattern_12, ' ', text)
    
    # Remove whitespace at the first and end sentences
    text = text.rstrip()
    text = text.lstrip()
    return text

indo_stop_words = stopwords.words("indonesian")

def remove_stopwords(text):
    return ' '.join([word for word in word_tokenize(text) if word not in indo_stop_words])
  
def tokenisasi(text):
  tokens = nltk.tokenize.word_tokenize(text)
  return tokens

# %%
df_coba = df.applymap(cleansing)
df_coba = df_coba.applymap(remove_stopwords)
df_coba['word_token'] = df_coba['data'].apply(tokenisasi)

# %%
df_coba
# Out:
#                                                     data     label  \
# 0      warung dimiliki pengusaha pabrik puluhan terke...  positive
# 1      mohon ulama lurus k mmbri hujjah partai diwlh ...   neutral
# 2      lokasi strategis jalan sumatera bandung nyaman...  positive
# 3      betapa bahagia unboxing paket barang bagus men...  positive
# 4      mahasiswa sombong kasih kartu kuning belajar u...  negative
# ...                                                  ...       ...
# 10995                                             kecewa  positive
# 10996  enak masakan kepiting menyenangkan memilih kep...  positive
# 10997                   hormati partai partai berkoalisi   neutral
# 10998        pagi pagi pasteur macet parah bikin jengkel  negative
# 10999  belanja yogya riau junction kali lihat foodlif...  positive
#
#                                               word_token
# 0      [warung, dimiliki, pengusaha, pabrik, puluhan,...
# ...

# %%
# membuat dictionary mapping
mapping = {'positive': 1, 'neutral': 0, 'negative': 2}

# %%
# mengubah nilai pada kolom 'label' dengan method apply
#df_coba['label'] = df_coba['label'].apply(lambda x: [mapping[i] for i in x]) --> hanya jika isi kolom 'label' berbentuk list atau array
df_coba['label'] = df_coba['label'].map(mapping)

# %%
df_coba
# Out:
#                                                     data  label  \
# 0      warung dimiliki pengusaha pabrik puluhan terke...      1
# 1      mohon ulama lurus k mmbri hujjah partai diwlh ...      0
# 2      lokasi strategis jalan sumatera bandung nyaman...      1
# 3      betapa bahagia unboxing paket barang bagus men...      1
# 4      mahasiswa sombong kasih kartu kuning belajar u...      2
# ...                                                  ...    ...
# 10995                                             kecewa      1
# 10996  enak masakan kepiting menyenangkan memilih kep...      1
# 10997                   hormati partai partai berkoalisi      0
# 10998        pagi pagi pasteur macet parah bikin jengkel      2
# 10999  belanja yogya riau junction kali lihat foodlif...      1
#
#                                               word_token
# 0      [warung, dimiliki, pengusaha, pabrik, puluhan,...
# 1      [mohon, ulama, lurus, k, mmbri, hujjah, partai...
# ...

# %%
# mengubah nilai pada kolom 'label' menjadi integer
#df_coba['label'] = df_coba['label'].apply(lambda x: x[0]).astype(int)

# %%
df_coba.to_csv('data_yang_sudah_ditokenisasi.csv', index=False)

# %%
from tqdm import tqdm

import numpy as np

# %%
# !pip install Sastrawi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 KB 5.2 MB/s eta 0:00:00
# ...

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory

# %%
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
# Memecah DataFrame menjadi empat DataFrame yang berisi 25% data masing-masing
df_list = np.array_split(df_coba, 10)
df1, df2, df3, df4, df5, df6, df7, df8, df9, df10 = df_list

# %%
# Melakukan analisis pada df1
df1_analysis = df1.describe()
df1_analysis
# Out:
#                  data     label
# count            1100      1100
# unique           1095         3
# top     marah indosat  positive
# freq                3       641

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df1

for i, row in tqdm(df1.iterrows(), total=df1.shape[0]):
    df1.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [02:15<00:00,  8.10it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df2

for i, row in tqdm(df2.iterrows(), total=df2.shape[0]):
    df2.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [02:40<00:00,  6.85it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df3

for i, row in tqdm(df3.iterrows(), total=df3.shape[0]):
    df3.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [02:23<00:00,  7.67it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df4

for i, row in tqdm(df4.iterrows(), total=df4.shape[0]):
    df4.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [01:53<00:00,  9.72it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df5

for i, row in tqdm(df5.iterrows(), total=df5.shape[0]):
    df5.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [01:55<00:00,  9.50it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df6

for i, row in tqdm(df6.iterrows(), total=df6.shape[0]):
    df6.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [01:42<00:00, 10.68it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df7

for i, row in tqdm(df7.iterrows(), total=df7.shape[0]):
    df7.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [01:32<00:00, 11.90it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df8

for i, row in tqdm(df8.iterrows(), total=df8.shape[0]):
    df8.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [01:23<00:00, 13.17it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df9

for i, row in tqdm(df9.iterrows(), total=df9.shape[0]):
    df9.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [01:26<00:00, 12.75it/s]

# %%
# Melakukan stemming pada kolom 'teks' pada DataFrame df10

for i, row in tqdm(df10.iterrows(), total=df10.shape[0]):
    df10.at[i, 'teks_stemmed'] = stemmer.stem(row['data'])
# Out:
# 100%|██████████| 1100/1100 [01:22<00:00, 13.30it/s]

# %%
# Menggabungkan kedua DataFrame secara vertikal
df_coba = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10], ignore_index=True)

# %%
df_coba.head()
# Out:
#                                                 data     label  \
# 0  warung dimiliki pengusaha pabrik puluhan terke...  positive
# 1  mohon ulama lurus k mmbri hujjah partai diwlh ...   neutral
# 2  lokasi strategis jalan sumatera bandung nyaman...  positive
# 3  betapa bahagia unboxing paket barang bagus men...  positive
# 4  mahasiswa sombong kasih kartu kuning belajar u...  negative
#
#                                         teks_stemmed
# 0  warung milik usaha pabrik puluh kenal putih ba...
# 1  mohon ulama lurus k mmbri hujjah partai diwlh ...
# 2  lokasi strategis jalan sumatera bandung nyaman...
# 3  betapa bahagia unboxing paket barang bagus tet...
# 4  mahasiswa sombong kasih kartu kuning ajar usah...

# %%
df_coba.tail()
# Out:
#                                                     data     label  \
# 10995                                             kecewa  positive
# 10996  enak masakan kepiting menyenangkan memilih kep...  positive
# 10997                   hormati partai partai berkoalisi   neutral
# 10998        pagi pagi pasteur macet parah bikin jengkel  negative
# 10999  belanja yogya riau junction kali lihat foodlif...  positive
#
#                                             teks_stemmed
# 10995                                             kecewa
# 10996  enak masakan kepiting senang pilih kepiting se...
# 10997                       hormat partai partai koalisi
# 10998        pagi pagi pasteur macet parah bikin jengkel
# 10999  belanja yogya riau junction kali lihat foodlif...

# %%
df_coba.to_csv('data_yang_sudah_distemmed.csv', index=False)
